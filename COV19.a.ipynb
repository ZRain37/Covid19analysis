# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
cov19 = pd.read_csv("~/Downloads/country_vaccinations.csv")

cov19.head(65)
# Out:
#     country iso_code        date  total_vaccinations  people_vaccinated  \
# 0   Albania      ALB  2021-01-10                 0.0                0.0
# 1   Albania      ALB  2021-01-11                 NaN                NaN
# 2   Albania      ALB  2021-01-12               128.0              128.0
# 3   Albania      ALB  2021-01-13               188.0              188.0
# 4   Albania      ALB  2021-01-14               266.0              266.0
# ..      ...      ...         ...                 ...                ...
# 60  Albania      ALB  2021-03-11                 NaN                NaN
# 61  Albania      ALB  2021-03-12             23635.0                NaN
# 62  Algeria      DZA  2021-01-29                 0.0                NaN
# 63  Algeria      DZA  2021-01-30                30.0                NaN
# 64  Algeria      DZA  2021-01-31                 NaN                NaN
#
#     people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
vacpop = cov19['vaccines'].value_counts()
vacpop.plot.bar(figsize = (20,10), cmap = 'Spectral')
# Out:
# <AxesSubplot:ylabel='vaccines'>

# %%
cotvac = cov19[['vaccines', 'country']].value_counts()
print(cotvac)
cotvac.plot.bar(figsize = (20,10))
# Out:
# vaccines                             country
# Oxford/AstraZeneca, Pfizer/BioNTech  Northern Ireland    92
#                                      England             92
# Moderna, Pfizer/BioNTech             Canada              92
# Oxford/AstraZeneca, Pfizer/BioNTech  United Kingdom      92
#                                      Scotland            92
#                                                          ..
# Oxford/AstraZeneca                   Uganda               6
#                                      Angola               4
# Sputnik V                            Tunisia              3
# Moderna                              Honduras             1
# Oxford/AstraZeneca                   Saint Helena         1
# Length: 137, dtype: int64
# <AxesSubplot:xlabel='vaccines,country'>

# %%
now = cov19.loc[:, ['country', 'date', 'people_vaccinated']]
print(now)
# Out:
#        country        date  people_vaccinated
# 0      Albania  2021-01-10                0.0
# 1      Albania  2021-01-11                NaN
# 2      Albania  2021-01-12              128.0
# 3      Albania  2021-01-13              188.0
# 4      Albania  2021-01-14              266.0
# ...        ...         ...                ...
# 6512  Zimbabwe  2021-03-11            36019.0
# 6513  Zimbabwe  2021-03-12            36283.0
# 6514  Zimbabwe  2021-03-13            36359.0
# 6515  Zimbabwe  2021-03-14            36359.0
# 6516  Zimbabwe  2021-03-15            37660.0
#
# [6517 rows x 3 columns]

# %%
now_df = cov19.loc[:, ['country', 'people_vaccinated']]
now_group = now_df.groupby('country')
now_max = now_group.max().sort_values('people_vaccinated')
print(now)
now_max.plot.bar(figsize = (20,10))
# Out:
#        country  people_vaccinated
# 0      Albania             6073.0
# 1      Algeria                NaN
# 2      Andorra             3650.0
# 3       Angola             6169.0
# 4     Anguilla             3929.0
# ..         ...                ...
# 132    Uruguay           212220.0
# 133  Venezuela            12194.0
# 134    Vietnam            15865.0
# 135      Wales          1122931.0
# 136   Zimbabwe            37660.0
#
# [137 rows x 2 columns]
# <AxesSubplot:xlabel='country'>
